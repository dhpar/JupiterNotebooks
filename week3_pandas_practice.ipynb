# %% [markdown]
# # Week 3 – Pandas Practice

# %%
import pandas as pd

# Example DataFrame
df = pd.DataFrame({'age':[22,35,27], 'score':[90,76,88]})
df

# %%
# Filtering
df[df['age'] > 25]

# %%
# Summary stats
df.describe()
