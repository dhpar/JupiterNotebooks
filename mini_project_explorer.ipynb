# %% [markdown]
# # Mini Project – Data Explorer
# Upload any CSV and start exploring.

# %%
import pandas as pd

# Load CSV
# df = pd.read_csv('your_file.csv')
# df.head()

# %%
# Basic cleaning
# df.isnull().sum()

# %%
# Plotting example
import matplotlib.pyplot as plt
# df['column'].hist()
# plt.show()
