# %% [markdown]
# # Week 1 – Python Basics for ML
# ## Reverse strings
#
# Basic Python exercises.

# %%
text = 'hello world'
text[::-1]
# Out:
# 'dlrow olleh'

# %% [markdown]
# ## Count characters in string
# The following Code counts the words inside a string.
#
# - len() - Build in function used to determine the length or number of items in various objects.
#
# - split() - Build in function to split a variable.

# %%
sentence = 'Machine learning with Python is fun.'
len(sentence.split())
# Out:
# 6

# %% [markdown]
# ## Math Operations

# %%
# Function for min, max, avg
nums = [3,7,1,9]
def stats(values):
    return min(values), max(values), sum(values)/len(values)
stats(nums)
# Out:
# (1, 9, 5.0)

# %% [markdown]
# ## Loops
# ### For loops
# For loops can iterate over a sequence of numbers using the "range" and "xrange" functions. The difference between range and xrange is that the range function returns a new list with numbers of that specified range, whereas xrange returns an iterator, which is more efficient. (Python 3 uses the range function, which acts like xrange). Note that the range function is zero based.

# %%
primes = [2, 3, 5, 7]
for prime in primes:
    print(prime)
# Out:
# 2
# 3
# 5
# 7

# %%
for x in range(3, 8, 2):
    print(x)
# Out:
# 3
# 5
# 7
