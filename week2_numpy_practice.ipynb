# %% [markdown]
# # Week 2 – NumPy Practice

# %%
import numpy as np
np.random.rand(3,3)

# %%
# Dot product
A = np.array([1,2,3])
B = np.array([4,5,6])
A.dot(B)

# %%
# Reshape example
arr = np.arange(9)
arr.reshape(3,3)
